# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import datasets
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/home/loki/Developer/Ml/Project/LinearRegression/car_data.csv')

# %%
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
df.fuel.value_counts()
# Out:
# fuel
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: count, dtype: int64

# %%
df.replace({'fuel':{'Petrol':0,'Diesel':1,'CNG':2,'LPG':3,'Electric':4}},inplace=True)
# Out:
# /tmp/ipykernel_18688/1991431406.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'fuel':{'Petrol':0,'Diesel':1,'CNG':2,'LPG':3,'Electric':4}},inplace=True)

# %%
df.sample(20)
# Out:
#                                         name  year  selling_price  km_driven  \
# 772        Volkswagen Polo 1.5 TDI Trendline  2011         220000      63657
# 4001                Maruti Celerio Green VXI  2017         365000      78000
# 2268                       Hyundai i10 Magna  2012         229999      49824
# 1935                 Mahindra KUV 100 G80 K2  2018         320000      30000
# 4159                          Tata Indigo LX  2012         125000     120000
# 3000               Hyundai i20 Sportz Petrol  2010         250000      40000
# 2232                    Maruti Alto LX BSIII  2008          85000     120000
# 1970                      Mahindra Bolero DI  2004         315000     110000
# 4236         Hyundai Grand i10 1.2 CRDi Asta  2018         465000      25000
# 583          Maruti S-Cross Zeta DDiS 200 SH  2015         750000      45974
# 3954                     Mahindra TUV 300 T8  2016         700000      40000
# ...

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven  fuel seller_type  \
# 0             Maruti 800 AC  2007          60000      70000     0  Individual
# 1  Maruti Wagon R LXI Minor  2007         135000      50000     0  Individual
# 2      Hyundai Verna 1.6 SX  2012         600000     100000     1  Individual
# 3    Datsun RediGO T Option  2017         250000      46000     0  Individual
# 4     Honda Amaze VX i-DTEC  2014         450000     141000     1  Individual
#
#   transmission         owner
# 0       Manual   First Owner
# 1       Manual   First Owner
# 2       Manual   First Owner
# 3       Manual   First Owner
# 4       Manual  Second Owner

# %%
df.seller_type.value_counts()
# Out:
# seller_type
# Individual          3244
# Dealer               994
# Trustmark Dealer     102
# Name: count, dtype: int64

# %%
df.replace({'seller_type':{'Individual':0,'Dealer':1,'Trustmark Dealer':2}},inplace=True)
# Out:
# /tmp/ipykernel_18688/321664593.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'seller_type':{'Individual':0,'Dealer':1,'Trustmark Dealer':2}},inplace=True)

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven  fuel  \
# 0             Maruti 800 AC  2007          60000      70000     0
# 1  Maruti Wagon R LXI Minor  2007         135000      50000     0
# 2      Hyundai Verna 1.6 SX  2012         600000     100000     1
# 3    Datsun RediGO T Option  2017         250000      46000     0
# 4     Honda Amaze VX i-DTEC  2014         450000     141000     1
#
#    seller_type transmission         owner
# 0            0       Manual   First Owner
# 1            0       Manual   First Owner
# 2            0       Manual   First Owner
# 3            0       Manual   First Owner
# 4            0       Manual  Second Owner

# %%
df.transmission.value_counts()
# Out:
# transmission
# Manual       3892
# Automatic     448
# Name: count, dtype: int64

# %%
df.replace({'transmission':{'Manual':0,'Automatic':1}},inplace=True)
# Out:
# /tmp/ipykernel_18688/3436730578.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'transmission':{'Manual':0,'Automatic':1}},inplace=True)

# %%
df.owner.value_counts()
# Out:
# owner
# First Owner             2832
# Second Owner            1106
# Third Owner              304
# Fourth & Above Owner      81
# Test Drive Car            17
# Name: count, dtype: int64

# %%
df.replace({'owner':{'First Owner':0,'Second Owner':1,'Third Owner':2,'Fourth & Above Owner':2,'Test Drive Car':3}},inplace=True)
# Out:
# /tmp/ipykernel_18688/198556119.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'owner':{'First Owner':0,'Second Owner':1,'Third Owner':2,'Fourth & Above Owner':2,'Test Drive Car':3}},inplace=True)

# %%
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#       fuel  seller_type  transmission  owner
# ...

# %%
Y=df.selling_price
X=df.drop(['name','selling_price'],axis=1)

# %%
model=LinearRegression()

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
X_train_predict=model.predict(X_train)
from sklearn.metrics import mean_absolute_error
mab_train=mean_absolute_error(Y_train,X_train_predict)
mab_train
# Out:
# 234597.98347966137
