# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

#load data
dataset=load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.iloc[0:10,5]
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7     True
# 8    False
# 9     True
# Name: job_work_from_home, dtype: bool

# %%
df.loc[1:10, 'salary_rate':'salary_hour_avg']
# Out:
#    salary_rate  salary_year_avg  salary_hour_avg
# 1         None              NaN              NaN
# 2         None              NaN              NaN
# 3         None              NaN              NaN
# 4         None              NaN              NaN
# 5         None              NaN              NaN
# 6         None              NaN              NaN
# 7         None              NaN              NaN
# 8         None              NaN              NaN
# 9         None              NaN              NaN
# 10        None              NaN              NaN

# %%
df.iloc[1]
# Out:
# job_title_short                                               Data Analyst
# job_title                                                     Data Analyst
# job_location                                  Guadalajara, Jalisco, Mexico
# job_via                                                   via BeBee México
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                     Mexico
# job_posted_date                                        2023-01-14 13:18:07
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                         Mexico
# salary_rate                                                           None
# ...

# %% [markdown]
# cleaning data

# %%
salary_year_median=df['salary_year_avg'].median()

# %%
salary_hour_median=df.salary_hour_avg.median()

# %%
df_filled=df
df_filled['salary_hour_avg']=df_filled['salary_hour_avg'].fillna(salary_hour_median)
df_filled['salary_year_avg']=df_filled['salary_year_avg'].fillna(salary_year_median)
df_filled
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df_filled.loc[1:10, 'salary_rate':'salary_hour_avg']
# Out:
#    salary_rate  salary_year_avg  salary_hour_avg
# 1         None         115000.0            45.98
# 2         None         115000.0            45.98
# 3         None         115000.0            45.98
# 4         None         115000.0            45.98
# 5         None         115000.0            45.98
# 6         None         115000.0            45.98
# 7         None         115000.0            45.98
# 8         None         115000.0            45.98
# 9         None         115000.0            45.98
# 10        None         115000.0            45.98

# %%
df_dropduplicate=df_filled
df_dropduplicate=df_dropduplicate.drop_duplicates()

# %%
df_dropduplicate.drop_duplicates(subset=['company_name','job_title_short'])
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785734      Business Analyst
# 785735  Senior Data Engineer
# 785736     Software Engineer
# 785738      Business Analyst
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785734                                  PreSales Engineer
# 785735                               Senior Data Engineer
# 785736                                    DevOps Engineer
# ...

# %%
df.loc[1:10,'salary_rate':'salary_hour_avg']
# Out:
#    salary_rate  salary_year_avg  salary_hour_avg
# 1         None         115000.0            45.98
# 2         None         115000.0            45.98
# 3         None         115000.0            45.98
# 4         None         115000.0            45.98
# 5         None         115000.0            45.98
# 6         None         115000.0            45.98
# 7         None         115000.0            45.98
# 8         None         115000.0            45.98
# 9         None         115000.0            45.98
# 10        None         115000.0            45.98

# %%
df_origianl=df.copy()

# %%
df_origianl.sample()
# Out:
#           job_title_short        job_title job_location       job_via  \
# 592596  Software Engineer  Product Analyst     Anywhere  via LinkedIn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 592596         Part-time                True  Texas, United States
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 592596  2023-11-03 09:01:20                   True                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 592596  United States        None         115000.0            45.98
#
#                                        company_name job_skills job_type_skills
# 592596  HustleWing - Side hustles for professionals       None            None

# %%
df.sample(10, random_state=42)
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
# 183426           Data Analyst
# 287790           Data Analyst
# 541983           Data Analyst
# 416896         Data Scientist
# 780907          Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
# 183426                                       Data Analyst
# 287790                                       Data Analyst
# 541983                   Data Analyst, Cloud Systems Jobs
# 416896             Alternant Actuariat & Data Science H/F
# ...

# %%
df.pivot_table(index='job_title_short',values='salary_year_avg',columns='job_country',aggfunc='median')
# Out:
# job_country                Afghanistan   Albania   Algeria    Angola  \
# job_title_short
# Business Analyst              115000.0  115000.0  115000.0  115000.0
# Cloud Engineer                     NaN  115000.0  115000.0       NaN
# Data Analyst                  115000.0  115000.0  115000.0  115000.0
# Data Engineer                      NaN  115000.0  115000.0  115000.0
# Data Scientist                115000.0  115000.0  115000.0  115000.0
# Machine Learning Engineer          NaN  115000.0  115000.0       NaN
# Senior Data Analyst           115000.0  115000.0       NaN       NaN
# Senior Data Engineer               NaN  115000.0  115000.0       NaN
# Senior Data Scientist              NaN  115000.0       NaN  115000.0
# Software Engineer                  NaN  115000.0  115000.0  115000.0
#
# job_country                Argentina   Armenia  Australia   Austria  \
# job_title_short
# Business Analyst            115000.0  115000.0   115000.0  115000.0
# ...

# %%
top_country=df.job_country.value_counts().head(5).index

# %%
df_job_country=df.pivot_table(
        index='job_country',
        columns='job_title_short',
        values='salary_year_avg',

    )

# %%
df_job_country=df_job_country.loc[top_country]
df_job_country
# Out:
# job_title_short  Business Analyst  Cloud Engineer   Data Analyst  \
# job_country
# United States       113900.923575   115240.704492  113688.506362
# India               114861.177001   115000.000000  114756.590917
# United Kingdom      114604.353083   115000.000000  114824.230681
# France              114862.432249   114973.278107  114878.922807
# Germany             114522.460220   115170.634921  114909.553639
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# United States    116597.655722   116930.687709              120453.603692
# India            115073.696044   115022.195911              114691.857675
# United Kingdom   115003.161853   114961.064714              115542.432177
# France           115004.184757   114904.590081              113953.889175
# Germany          115089.252434   115013.739066              114891.616915
#
# job_title_short  Senior Data Analyst  Senior Data Engineer  \
# job_country
# ...

# %%
job_titles=['Business Analyst','Data Analyst',"Data Scientist"]
df_job_country=df_job_country[job_titles]
df_job_country
# Out:
# job_title_short  Business Analyst   Data Analyst  Data Scientist
# job_country
# United States       113900.923575  113688.506362   116930.687709
# India               114861.177001  114756.590917   115022.195911
# United Kingdom      114604.353083  114824.230681   114961.064714
# France              114862.432249  114878.922807   114904.590081
# Germany             114522.460220  114909.553639   115013.739066

# %%
df_job_country.plot(kind='bar')
plt.xlabel('job_title')
plt.ylabel('salary in usd')
plt.show()
